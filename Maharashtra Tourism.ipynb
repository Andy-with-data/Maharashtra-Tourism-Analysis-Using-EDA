# %% [markdown]
# # MAHARASHTRA TOURISM:

# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\Aniket\OneDrive\Desktop\torist.csv')

# %%
data.head()       # it will show 1st 5 row 
data.tail()       # it will show last 5 row
# Out:
#     id   year        state district           destination   tourist  \
# 94   95  2019  maharashtra  RAIGHAD            PRATAPGARH  Domestic
# 95   96  2019  maharashtra   MUMBAI  Jahangir art gallery   Foreign
# 96   97  2019  maharashtra   MUMBAI  Jahangir art gallery   Foreign
# 97   98  2019  maharashtra     PUNE         Shivneri Fort  Domestic
# 98   99  2019  maharashtra     PUNE         Shivneri Fort  Domestic
#
#    Overnight Tourists  total visotor arrived  accomodation unit  days stay  \
# 94   within the state                     99                  1          1
# 95    outside country                   2458                  2          2
# 96    outside country                    259                  1          3
# 97   within the state                   6812                  6          3
# 98  outside the state                    458                  2          4
#
#    Mode of Transportation Travel Arrangement Mode  \
# 94                  Train           Tour Operator
# ...

# %%
data.isnull().sum()       # it will show null values count 
data.isna().sum()       # it will show null values count
# Out:
# id                                  0
# year                                0
# state                               0
# district                            0
# destination                         0
# tourist                             0
# Overnight Tourists                  0
# total visotor arrived               0
# accomodation unit                   0
# days stay                           0
# Mode of Transportation              0
# Travel Arrangement Mode             0
# Total number of Foreign Visitors    0
# dtype: int64

# %%
data.head()
# Out:
#    id   year        state    district  destination   tourist  \
# 0    1  2019  maharashtra  AHMEDNAGAR       Shirdi  Domestic
# 1    2  2020  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 2    3  2021  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 3    4  2022  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 4    5  2020  maharashtra  AHMEDNAGAR  Bhandardara  Domestic
#
#   Overnight Tourists  total visotor arrived  accomodation unit  days stay  \
# 0  outside the state                  17593                  3          1
# 1    outside country                   8545                  4          2
# 2    outside country                   1365                  5          3
# 3    outside country                    125                  5          1
# 4  outside the state                   1102                  2          2
#
#   Mode of Transportation Travel Arrangement Mode  \
# 0                  Train           Tour Operator
# 1                    Air           Tour Operator
# ...

# %%
data.isna().any().sum()     #This function gives output in a single value if any null is present or not.
# Out:
# 0

# %%
data.duplicated().sum()
# Out:
# 0

# %%
ani=['Travel Arrangement Mode']

# %%
#data.drop(ani,inplace=True,axis=1)       # want to delete any column then use drop function
#data.dr

# %%
data.head()
# Out:
#    id   year        state    district  destination   tourist  \
# 0    1  2019  maharashtra  AHMEDNAGAR       Shirdi  Domestic
# 1    2  2020  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 2    3  2021  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 3    4  2022  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 4    5  2020  maharashtra  AHMEDNAGAR  Bhandardara  Domestic
#
#   Overnight Tourists  total visotor arrived  accomodation unit  days stay  \
# 0  outside the state                  17593                  3          1
# 1    outside country                   8545                  4          2
# 2    outside country                   1365                  5          3
# 3    outside country                    125                  5          1
# 4  outside the state                   1102                  2          2
#
#   Mode of Transportation Travel Arrangement Mode  \
# 0                  Train           Tour Operator
# 1                    Air           Tour Operator
# ...

# %%
data.loc[15]       #We can access each record in a straightforward way with loc[]. Although loc[] may not have all that intuitive of a name, it allows us to do label-based indexing, which is the labeling of a row or record without regard to its position:
# Out:
# id                                                             16
# year                                                         2022
# state                                                 maharashtra
# district                                                 KOLHAPUR
# destination                                      Mahalaxmi Temple
# tourist                                                  Domestic
# Overnight Tourists                              outside the state
# total visotor arrived                                         266
# accomodation unit                                               6
# days stay                                                       6
# Mode of Transportation                           Personal Vehicle
# Travel Arrangement Mode                                      Self
# Total number of Foreign Visitors                            delhi
# Date_new                            1970-01-01 00:00:00.000002022
# Name: 15, dtype: object

# %%
# data.set_index("First Name", inplace = True)       # setting first name as index column

# %%
data['Overnight Tourists']        # acess the perticular column
# Out:
# 0     outside the state
# 1       outside country
# 2       outside country
# 3       outside country
# 4     outside the state
#             ...
# 94     within the state
# 95      outside country
# 96      outside country
# 97     within the state
# 98    outside the state
# Name: Overnight Tourists, Length: 99, dtype: object

# %%
data['Overnight Tourists'].str.contains('outside the state').sum()
# Out:
# 35

# %%
data.loc[7,'state']='maharashtra'      # changing values of specific row

# %%
data.head(10)
# Out:
#    id   year        state    district             destination   tourist  \
# 0    1  2019  maharashtra  AHMEDNAGAR                  Shirdi  Domestic
# 1    2  2020  maharashtra  AHMEDNAGAR                  Shirdi   Foreign
# 2    3  2021  maharashtra  AHMEDNAGAR                  Shirdi   Foreign
# 3    4  2022  maharashtra  AHMEDNAGAR                  Shirdi   Foreign
# 4    5  2020  maharashtra  AHMEDNAGAR             Bhandardara  Domestic
# 5    6  2021  maharashtra  AHMEDNAGAR             Bhandardara  Domestic
# 6    7  2022  maharashtra  AHMEDNAGAR             Bhandardara  Domestic
# 7    8  2020  maharashtra  AHMEDNAGAR  Kalasubai Harischandra  Domestic
# 8    9  2021  maharashtra  AHMEDNAGAR  Kalasubai Harischandra  Domestic
# 9   10  2022  maharashtra    KOLHAPUR        Mahalaxmi Temple   Foreign
#
#   Overnight Tourists  total visotor arrived  accomodation unit  days stay  \
# 0  outside the state                  17593                  3          1
# ...

# %%
data.dtypes
# Out:
# id                                   int64
# year                                 int64
# state                               object
# district                            object
# destination                         object
# tourist                             object
# Overnight Tourists                  object
# total visotor arrived                int64
# accomodation unit                    int64
# days stay                            int64
# Mode of Transportation              object
# Total number of Foreign Visitors    object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                99 non-null     int64
#  1   year                              99 non-null     int64
#  2   state                             99 non-null     object
#  3   district                          99 non-null     object
#  4   destination                       99 non-null     object
#  5   tourist                           99 non-null     object
#  6   Overnight Tourists                99 non-null     object
#  7   total visotor arrived             99 non-null     int64
#  8   accomodation unit                 99 non-null     int64
#  9   days stay                         99 non-null     int64
#  10  Mode of Transportation            99 non-null     object
#  11  Total number of Foreign Visitors  99 non-null     object
# ...

# %%
import seaborn as sns

# %%
data['Date_new']=pd.to_datetime(data['year'])

# %%
data.head()
# Out:
#    id   year        state    district  destination   tourist  \
# 0    1  2019  maharashtra  AHMEDNAGAR       Shirdi  Domestic
# 1    2  2020  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 2    3  2021  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 3    4  2022  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 4    5  2020  maharashtra  AHMEDNAGAR  Bhandardara  Domestic
#
#   Overnight Tourists  total visotor arrived  accomodation unit  days stay  \
# 0  outside the state                  17593                  3          1
# 1    outside country                   8545                  4          2
# 2    outside country                   1365                  5          3
# 3    outside country                    125                  5          1
# 4  outside the state                   1102                  2          2
#
#   Mode of Transportation Travel Arrangement Mode  \
# 0                  Train           Tour Operator
# 1                    Air           Tour Operator
# ...

# %%
data.dtypes
# Out:
# id                                           int64
# year                                         int64
# state                                       object
# district                                    object
# destination                                 object
# tourist                                     object
# Overnight Tourists                          object
# total visotor arrived                        int64
# accomodation unit                            int64
# days stay                                    int64
# Mode of Transportation                      object
# Total number of Foreign Visitors            object
# Date_new                            datetime64[ns]
# dtype: object

# %%
ani=['Date_new']

# %%
data.drop(columns=ani, inplace=True)

# %%
data.head()
# Out:
#    id   year        state    district  destination   tourist  \
# 0    1  2019  maharashtra  AHMEDNAGAR       Shirdi  Domestic
# 1    2  2020  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 2    3  2021  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 3    4  2022  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 4    5  2020  maharashtra  AHMEDNAGAR  Bhandardara  Domestic
#
#   Overnight Tourists  total visotor arrived  accomodation unit  days stay  \
# 0  outside the state                  17593                  3          1
# 1    outside country                   8545                  4          2
# 2    outside country                   1365                  5          3
# 3    outside country                    125                  5          1
# 4  outside the state                   1102                  2          2
#
#   Mode of Transportation Total number of Foreign Visitors
# 0                  Train                            delhi
# ...

# %%
data.head(10)
# Out:
#    id   year        state    district             destination   tourist  \
# 0    1  2019  maharashtra  AHMEDNAGAR                  Shirdi  Domestic
# 1    2  2020  maharashtra  AHMEDNAGAR                  Shirdi   Foreign
# 2    3  2021  maharashtra  AHMEDNAGAR                  Shirdi   Foreign
# 3    4  2022  maharashtra  AHMEDNAGAR                  Shirdi   Foreign
# 4    5  2020  maharashtra  AHMEDNAGAR             Bhandardara  Domestic
# 5    6  2021  maharashtra  AHMEDNAGAR             Bhandardara  Domestic
# 6    7  2022  maharashtra  AHMEDNAGAR             Bhandardara  Domestic
# 7    8  2020  maharashtra  AHMEDNAGAR  Kalasubai Harischandra  Domestic
# 8    9  2021  maharashtra  AHMEDNAGAR  Kalasubai Harischandra  Domestic
# 9   10  2022  maharashtra    KOLHAPUR        Mahalaxmi Temple   Foreign
#
#   Overnight Tourists  total visotor arrived  accomodation unit  days stay  \
# 0  outside the state                  17593                  3          1
# ...

# %%
data.groupby('tourist').tourist.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 data.groupby('tourist').tourist.count()
#
# AttributeError: module 'plotly.express.data' has no attribute 'groupby'

# %%
data.groupby('tourist').tourist.count().plot(kind='bar',color='green')   
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 data.groupby('tourist').tourist.count().plot(kind='bar',color='green')
#       2 import matplotlib.pyplot as plt
#
# AttributeError: module 'plotly.express.data' has no attribute 'groupby'

# %%
t=data[(data['tourist']=='Domestic') & (data['total visotor arrived']>500)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 t=data[(data['tourist']=='Domestic') & (data['total visotor arrived']>500)]
#
# TypeError: 'module' object is not subscriptable

# %%
t
# Out:
#     id   year        state    district             destination   tourist  \
# 0     1  2019  maharashtra  AHMEDNAGAR                  Shirdi  Domestic
# 4     5  2020  maharashtra  AHMEDNAGAR             Bhandardara  Domestic
# 7     8  2020  maharashtra  AHMEDNAGAR  Kalasubai Harischandra  Domestic
# 8     9  2021  maharashtra  AHMEDNAGAR  Kalasubai Harischandra  Domestic
# 14   15  2021  maharashtra    KOLHAPUR        Mahalaxmi Temple  Domestic
# 16   17  2020  maharashtra    KOLHAPUR        Mahalaxmi Temple  Domestic
# 27   28  2022  maharashtra      MUMBAI            Marine Drive  Domestic
# 34   35  2022  maharashtra        PUNE                LONAVALE  Domestic
# 39   40  2022  maharashtra        PUNE             Panchet Dam  Domestic
# 43   44  2022  maharashtra        PUNE                 Sinhgad  Domestic
# 55   56  2021  maharashtra   RATNAGIRI             Ganpatipule  Domestic
# 65   66  2021  maharashtra  SINDHUDURG            Malvan beach  Domestic
# ...

# %%
data['total visotor arrived'].value_counts().head(6)
# Out:
# 2458    4
# 369     4
# 20      4
# 25      4
# 579     4
# 266     4
# Name: total visotor arrived, dtype: int64

# %%
data['days stay'].max()
# Out:
# 9

# %%
data['days stay'].min()
# Out:
# 0

# %%
x=data['total visotor arrived'].max()

# %%
x
# Out:
# 17593

# %%
data[data['Mode of Transportation']=='Train']
# Out:
#     id   year        state    district        destination   tourist  \
# 0     1  2019  maharashtra  AHMEDNAGAR             Shirdi  Domestic
# 56   57  2021  maharashtra   RATNAGIRI        Ganpatipule  Domestic
# 57   58  2021  maharashtra   RATNAGIRI        Ganpatipule  Domestic
# 64   65  2021  maharashtra  SINDHUDURG       Malvan beach  Domestic
# 65   66  2021  maharashtra  SINDHUDURG       Malvan beach  Domestic
# 66   67  2021  maharashtra  SINDHUDURG       Malvan beach  Domestic
# 67   68  2021  maharashtra  SINDHUDURG  Amboli Waterfalls  Domestic
# 68   69  2021  maharashtra  SINDHUDURG  Amboli Waterfalls  Domestic
# 69   70  2021  maharashtra  SINDHUDURG  Amboli Waterfalls  Domestic
# 70   71  2021  maharashtra  SINDHUDURG  Amboli Waterfalls  Domestic
# 74   75  2020  maharashtra      SATARA      Mahabaleshwar  Domestic
# 75   76  2020  maharashtra      SATARA      Mahabaleshwar  Domestic
# 76   77  2020  maharashtra      SATARA          Panchgani  Domestic
# ...

# %%
data.iloc[1:7]
# Out:
#    id   year        state    district  destination   tourist  \
# 1    2  2020  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 2    3  2021  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 3    4  2022  maharashtra  AHMEDNAGAR       Shirdi   Foreign
# 4    5  2020  maharashtra  AHMEDNAGAR  Bhandardara  Domestic
# 5    6  2021  maharashtra  AHMEDNAGAR  Bhandardara  Domestic
# 6    7  2022  maharashtra  AHMEDNAGAR  Bhandardara  Domestic
#
#   Overnight Tourists  total visotor arrived  accomodation unit  days stay  \
# 1    outside country                   8545                  4          2
# 2    outside country                   1365                  5          3
# 3    outside country                    125                  5          1
# 4  outside the state                   1102                  2          2
# 5  outside the state                    256                  5          2
# 6  outside the state                    259                  8          5
#
# ...

# %%
sns.distplot(data['year'],color='blue',hist=False)
plt.show()
# Out:
# C:\Users\Aniket\AppData\Local\Temp\ipykernel_25516\1540608958.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['year'],color='blue',hist=False)

# %%
sns.set(style="whitegrid")
res=sns.barplot(x='year',y='total visotor arrived',data=data,palette='rocket')
plt.show()

# %%
sns.countplot(x="year",data=data,color="green",hue="Overnight Tourists",palette="mako",saturation=0.8)
plt.show()

# %%
sns.lineplot(x="year",y="days stay",data=data)
plt.show()

# %%
sns.scatterplot(data=data, x="year", y="total visotor arrived",hue="Mode of Transportation")
# Out:
# <Axes: xlabel='year', ylabel='total visotor arrived'>
